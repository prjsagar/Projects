# %%
import pandas as pd

# %%
df=pd.read_excel(r"C:\Data Analyst\WebScrape\Customer Call List.xlsx")
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df=df.drop_duplicates()
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df=df.drop(columns='Not_Useful_Column')
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df['Last_Name']=df['Last_Name'].str.strip('123./_')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White    7066950392
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry      Potter    7066950392
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %%
df["Phone_Number"]=df["Phone_Number"].str.replace('[^a-zA-Z0-9]','',regex=True)

df['Phone_Number']=df['Phone_Number'].apply(lambda x:str(x))

df['Phone_Number']=df['Phone_Number'].apply(lambda x:x[0:3]+"-"+x[3:6]+"-"+x[6:10])

df['Phone_Number']=df['Phone_Number'].str.replace('nan--','',regex=True)

df['Phone_Number']=df['Phone_Number'].str.replace('Na--','',regex=True)

# %%
df[['Street_Address','State','Zip_Code' ]]=df['Address'].str.split(',',expand=True)
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
df['Paying Customer']=df['Paying Customer'].str.replace('Y','Yes')
df['Paying Customer']=df['Paying Customer'].str.replace('N','No')

df['Paying Customer']
# Out:
# 0     Yes
# 1      No
# 2      No
# 3     Yes
# 4     Yes
# 5     Yes
# 6      No
# 7      No
# 8     Yes
# 9     Yes
# 10    Yes
# 11    Yes
# 12    Yes
# 13    Yes
# 14     No
# 15     No
# 16    Yes
# 17    Yes
# 18
# 19    Yes
# Name: Paying Customer, dtype: object

# %%
df['Do_Not_Contact']=df['Do_Not_Contact'].str.replace('Y','Yes')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
df=df.replace('N/a','')
df.fillna('')
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
for x in df.index:
    if df.loc[x,'Paying Customer']=='':
        df.drop(x,inplace=True)

df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent
# 19        1020     Anakin   Skywalker  876-678-3469
# ...

# %%
df.fillna('')
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 8         1009    Gandalf
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 11        1012      Harry      Potter
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 17        1018      Clark        Kent
# 19        1020     Anakin   Skywalker  876-678-3469
#
# ...

# %%
for x in df.index:
    if df.loc[x,'Paying Customer']=='Yes':
        df.drop(x,inplace=True)

df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number               Address  \
# 1         1002       Abed       Nadir  123-643-9775   93 West Main Street
# 5         1007       Jeff      Winger                   1209 South Street
# 6         1008   Sherlock      Holmes  876-678-3469         98 Clue Drive
# 11        1015       Toby  Flenderson  304-762-2467         214 HR Avenue
# 12        1016        Ron     Weasley  123-545-5421  2395 Hogwarts Avenue
#
#    Paying Customer Do_Not_Contact        Street_Address State Zip_Code
# 1               No            Yes   93 West Main Street
# 5               No             No     1209 South Street
# 6               No             No         98 Clue Drive
# 11              No             No         214 HR Avenue
# 12              No             No  2395 Hogwarts Avenue

# %%
df.fillna('',inplace=True)

# %%
for x in df.index:
    if df.loc[x,'Do_Not_Contact']=='':
        df.drop(x,inplace=True)

df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123-643-9775
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876-678-3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-678-3469
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876-678-3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123-643-9775
# 19        1020     Anakin   Skywalker  876-678-3469
#
#                                   Address Paying Customer Do_Not_Contact  \
# 0                   123 Shire Lane, Shire             Yes             No
# ...

# %%
df=df.reset_index(drop=True)

# %%
df['Paying Customer'].reset_index()
# Out:
#    index Paying Customer
# 0      1              No
# 1      5              No
# 2      6              No
# 3     11              No
# 4     12              No

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number               Address  \
# 1         1002       Abed       Nadir  123-643-9775   93 West Main Street
# 5         1007       Jeff      Winger                   1209 South Street
# 6         1008   Sherlock      Holmes  876-678-3469         98 Clue Drive
# 11        1015       Toby  Flenderson  304-762-2467         214 HR Avenue
# 12        1016        Ron     Weasley  123-545-5421  2395 Hogwarts Avenue
#
#    Paying Customer Do_Not_Contact        Street_Address State Zip_Code
# 1               No            Yes   93 West Main Street
# 5               No             No     1209 South Street
# 6               No             No         98 Clue Drive
# 11              No             No         214 HR Avenue
# 12              No             No  2395 Hogwarts Avenue

# %%
df.reset_index(drop=True)
# Out:
#    CustomerID First_Name   Last_Name  Phone_Number               Address  \
# 0        1002       Abed       Nadir  123-643-9775   93 West Main Street
# 1        1007       Jeff      Winger                   1209 South Street
# 2        1008   Sherlock      Holmes  876-678-3469         98 Clue Drive
# 3        1015       Toby  Flenderson  304-762-2467         214 HR Avenue
# 4        1016        Ron     Weasley  123-545-5421  2395 Hogwarts Avenue
#
#   Paying Customer Do_Not_Contact        Street_Address State Zip_Code
# 0              No            Yes   93 West Main Street
# 1              No             No     1209 South Street
# 2              No             No         98 Clue Drive
# 3              No             No         214 HR Avenue
# 4              No             No  2395 Hogwarts Avenue

# %%
for x in df.index:
    if df.loc[x,'Do_Not_Contact']=='Yes':
        df.drop(x,inplace=True)

df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number               Address  \
# 5         1007       Jeff      Winger                   1209 South Street
# 6         1008   Sherlock      Holmes  876-678-3469         98 Clue Drive
# 11        1015       Toby  Flenderson  304-762-2467         214 HR Avenue
# 12        1016        Ron     Weasley  123-545-5421  2395 Hogwarts Avenue
#
#    Paying Customer Do_Not_Contact        Street_Address State Zip_Code
# 5               No             No     1209 South Street
# 6               No             No         98 Clue Drive
# 11              No             No         214 HR Avenue
# 12              No             No  2395 Hogwarts Avenue

# %%
df.reset_index(drop=True)
# Out:
#    CustomerID First_Name   Last_Name  Phone_Number               Address  \
# 0        1007       Jeff      Winger                   1209 South Street
# 1        1008   Sherlock      Holmes  876-678-3469         98 Clue Drive
# 2        1015       Toby  Flenderson  304-762-2467         214 HR Avenue
# 3        1016        Ron     Weasley  123-545-5421  2395 Hogwarts Avenue
#
#   Paying Customer Do_Not_Contact        Street_Address State Zip_Code
# 0              No             No     1209 South Street
# 1              No             No         98 Clue Drive
# 2              No             No         214 HR Avenue
# 3              No             No  2395 Hogwarts Avenue

# %%
df.to_csv(r'C:\Data Analyst\Clean Customer List.csv')

# %%
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number               Address  \
# 5         1007       Jeff      Winger                   1209 South Street
# 6         1008   Sherlock      Holmes  876-678-3469         98 Clue Drive
# 11        1015       Toby  Flenderson  304-762-2467         214 HR Avenue
# 12        1016        Ron     Weasley  123-545-5421  2395 Hogwarts Avenue
#
#    Paying Customer Do_Not_Contact        Street_Address State Zip_Code
# 5               No             No     1209 South Street
# 6               No             No         98 Clue Drive
# 11              No             No         214 HR Avenue
# 12              No             No  2395 Hogwarts Avenue

# %%
df=df.reset_index(drop=True)

# %%
df
# Out:
#    CustomerID First_Name   Last_Name  Phone_Number               Address  \
# 0        1007       Jeff      Winger                   1209 South Street
# 1        1008   Sherlock      Holmes  876-678-3469         98 Clue Drive
# 2        1015       Toby  Flenderson  304-762-2467         214 HR Avenue
# 3        1016        Ron     Weasley  123-545-5421  2395 Hogwarts Avenue
#
#   Paying Customer Do_Not_Contact        Street_Address State Zip_Code
# 0              No             No     1209 South Street
# 1              No             No         98 Clue Drive
# 2              No             No         214 HR Avenue
# 3              No             No  2395 Hogwarts Avenue

# %%
df.to_csv(r'C:\Data Analyst\Clean Customer List.csv')
